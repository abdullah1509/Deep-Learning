# %% [markdown]
# # Regression

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.utils import plot_model
from tensorflow.keras.datasets import boston_housing
from sklearn import preprocessing
from sklearn.preprocessing import scale

# %%
(x_train, y_train), (x_test, y_test)= boston_housing.load_data()
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
# Out:
# (404, 13) (102, 13) (404,) (102,)

# %%
scaler= preprocessing.StandardScaler().fit(x_train)

x_trainn_scaled= scaler.transform(x_train)
x_test_scaled= scaler.transform(x_test)

# %%
print(x_trainn_scaled.shape, x_test_scaled.shape)
# Out:
# (404, 13) (102, 13)

# %%
model= Sequential()
model.add(Dense(64, input_dim=13, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(16, activation='relu'))
model.add(Dense(1))

# %%
plot_model(model, show_layer_names=True, show_shapes=True)

# %%
import tensorflow as tf
model.compile(loss=tf.keras.losses.MeanSquaredError(), 
              optimizer=tf.keras.optimizers.Adam(), 
              metrics=['mean_absolute_error'])



# OR

#model.compile(loss='mse', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(x_trainn_scaled, y_train, batch_size=32, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 13/13 - 1s - loss: 3.0540 - mean_absolute_error: 1.2955
# Epoch 2/100
# 13/13 - 0s - loss: 3.3197 - mean_absolute_error: 1.3247
# Epoch 3/100
# 13/13 - 0s - loss: 3.1444 - mean_absolute_error: 1.2732
# Epoch 4/100
# 13/13 - 0s - loss: 2.9143 - mean_absolute_error: 1.2191
# Epoch 5/100
# 13/13 - 0s - loss: 3.0339 - mean_absolute_error: 1.2558
# Epoch 6/100
# 13/13 - 0s - loss: 3.0699 - mean_absolute_error: 1.2755
# Epoch 7/100
# 13/13 - 0s - loss: 2.9324 - mean_absolute_error: 1.2827
# Epoch 8/100
# 13/13 - 0s - loss: 2.8267 - mean_absolute_error: 1.2251
# Epoch 9/100
# 13/13 - 0s - loss: 2.8307 - mean_absolute_error: 1.2037
# Epoch 10/100
# 13/13 - 0s - loss: 3.0374 - mean_absolute_error: 1.2353
# Epoch 11/100
# 13/13 - 0s - loss: 2.9616 - mean_absolute_error: 1.2764
# Epoch 12/100
# 13/13 - 0s - loss: 2.8500 - mean_absolute_error: 1.2552
# Epoch 13/100
# 13/13 - 0s - loss: 3.2759 - mean_absolute_error: 1.2959
# Epoch 14/100
# 13/13 - 0s - loss: 3.7071 - mean_absolute_error: 1.2895
# Epoch 15/100
# 13/13 - 0s - loss: 3.0852 - mean_absolute_error: 1.2486
# Epoch 16/100
# 13/13 - 0s - loss: 2.8920 - mean_absolute_error: 1.2134
# Epoch 17/100
# 13/13 - 0s - loss: 3.3487 - mean_absolute_error: 1.3330
# Epoch 18/100
# 13/13 - 0s - loss: 3.0515 - mean_absolute_error: 1.2736
# Epoch 19/100
# 13/13 - 0s - loss: 3.5496 - mean_absolute_error: 1.3245
# Epoch 20/100
# 13/13 - 0s - loss: 2.8789 - mean_absolute_error: 1.1940
# Epoch 21/100
# 13/13 - 0s - loss: 3.0619 - mean_absolute_error: 1.2457
# Epoch 22/100
# 13/13 - 0s - loss: 2.5506 - mean_absolute_error: 1.2013
# Epoch 23/100
# 13/13 - 0s - loss: 3.3678 - mean_absolute_error: 1.2577
# Epoch 24/100
# 13/13 - 0s - loss: 3.1173 - mean_absolute_error: 1.2386
# Epoch 25/100
# 13/13 - 0s - loss: 3.0238 - mean_absolute_error: 1.2063
# Epoch 26/100
# 13/13 - 0s - loss: 2.8703 - mean_absolute_error: 1.2231
# Epoch 27/100
# 13/13 - 0s - loss: 2.9181 - mean_absolute_error: 1.2369
# Epoch 28/100
# 13/13 - 0s - loss: 3.2017 - mean_absolute_error: 1.2385
# Epoch 29/100
# 13/13 - 0s - loss: 2.9530 - mean_absolute_error: 1.2138
# Epoch 30/100
# 13/13 - 0s - loss: 2.7761 - mean_absolute_error: 1.2247
# Epoch 31/100
# 13/13 - 0s - loss: 2.9815 - mean_absolute_error: 1.2641
# Epoch 32/100
# 13/13 - 0s - loss: 2.6273 - mean_absolute_error: 1.1833
# Epoch 33/100
# 13/13 - 0s - loss: 4.1196 - mean_absolute_error: 1.3846
# Epoch 34/100
# 13/13 - 0s - loss: 3.3160 - mean_absolute_error: 1.2779
# Epoch 35/100
# 13/13 - 0s - loss: 2.7253 - mean_absolute_error: 1.2259
# Epoch 36/100
# 13/13 - 0s - loss: 3.3879 - mean_absolute_error: 1.2771
# Epoch 37/100
# 13/13 - 0s - loss: 2.4342 - mean_absolute_error: 1.1458
# Epoch 38/100
# 13/13 - 0s - loss: 3.0532 - mean_absolute_error: 1.2594
# Epoch 39/100
# 13/13 - 0s - loss: 2.2983 - mean_absolute_error: 1.1345
# Epoch 40/100
# 13/13 - 0s - loss: 2.8882 - mean_absolute_error: 1.1940
# Epoch 41/100
# 13/13 - 0s - loss: 3.3753 - mean_absolute_error: 1.3062
# Epoch 42/100
# 13/13 - 0s - loss: 3.2477 - mean_absolute_error: 1.2620
# Epoch 43/100
# 13/13 - 0s - loss: 3.0280 - mean_absolute_error: 1.2457
# Epoch 44/100
# 13/13 - 0s - loss: 2.7849 - mean_absolute_error: 1.2493
# Epoch 45/100
# 13/13 - 0s - loss: 2.8518 - mean_absolute_error: 1.2569
# Epoch 46/100
# 13/13 - 0s - loss: 2.8678 - mean_absolute_error: 1.2314
# Epoch 47/100
# 13/13 - 0s - loss: 3.1223 - mean_absolute_error: 1.2554
# Epoch 48/100
# 13/13 - 0s - loss: 2.6111 - mean_absolute_error: 1.1936
# Epoch 49/100
# 13/13 - 0s - loss: 3.2887 - mean_absolute_error: 1.3038
# Epoch 50/100
# 13/13 - 0s - loss: 2.8956 - mean_absolute_error: 1.2390
# Epoch 51/100
# 13/13 - 0s - loss: 3.1183 - mean_absolute_error: 1.2367
# Epoch 52/100
# 13/13 - 0s - loss: 2.8469 - mean_absolute_error: 1.2488
# Epoch 53/100
# 13/13 - 0s - loss: 2.8602 - mean_absolute_error: 1.2037
# Epoch 54/100
# 13/13 - 0s - loss: 2.6258 - mean_absolute_error: 1.1747
# Epoch 55/100
# 13/13 - 0s - loss: 3.1556 - mean_absolute_error: 1.2124
# Epoch 56/100
# 13/13 - 0s - loss: 2.5483 - mean_absolute_error: 1.1769
# Epoch 57/100
# 13/13 - 0s - loss: 2.6365 - mean_absolute_error: 1.2018
# Epoch 58/100
# 13/13 - 0s - loss: 2.5955 - mean_absolute_error: 1.2107
# Epoch 59/100
# 13/13 - 0s - loss: 3.1533 - mean_absolute_error: 1.2632
# Epoch 60/100
# 13/13 - 0s - loss: 2.4768 - mean_absolute_error: 1.1730
# Epoch 61/100
# 13/13 - 0s - loss: 2.7010 - mean_absolute_error: 1.2020
# Epoch 62/100
# 13/13 - 0s - loss: 2.7122 - mean_absolute_error: 1.1744
# Epoch 63/100
# 13/13 - 0s - loss: 2.9102 - mean_absolute_error: 1.2082
# Epoch 64/100
# 13/13 - 0s - loss: 2.8568 - mean_absolute_error: 1.2221
# Epoch 65/100
# 13/13 - 0s - loss: 3.3852 - mean_absolute_error: 1.2727
# Epoch 66/100
# 13/13 - 0s - loss: 2.4367 - mean_absolute_error: 1.1109
# Epoch 67/100
# 13/13 - 0s - loss: 2.8653 - mean_absolute_error: 1.1842
# Epoch 68/100
# 13/13 - 0s - loss: 2.6214 - mean_absolute_error: 1.1663
# Epoch 69/100
# 13/13 - 0s - loss: 2.8549 - mean_absolute_error: 1.1927
# Epoch 70/100
# 13/13 - 0s - loss: 3.0868 - mean_absolute_error: 1.2175
# Epoch 71/100
# 13/13 - 0s - loss: 2.8503 - mean_absolute_error: 1.1813
# Epoch 72/100
# 13/13 - 0s - loss: 2.6510 - mean_absolute_error: 1.2083
# Epoch 73/100
# 13/13 - 0s - loss: 3.0372 - mean_absolute_error: 1.2215
# Epoch 74/100
# 13/13 - 0s - loss: 2.7448 - mean_absolute_error: 1.2016
# Epoch 75/100
# 13/13 - 0s - loss: 2.4171 - mean_absolute_error: 1.1423
# Epoch 76/100
# 13/13 - 0s - loss: 2.6588 - mean_absolute_error: 1.1528
# Epoch 77/100
# 13/13 - 0s - loss: 2.6528 - mean_absolute_error: 1.1837
# Epoch 78/100
# 13/13 - 0s - loss: 2.3695 - mean_absolute_error: 1.1337
# Epoch 79/100
# 13/13 - 0s - loss: 2.3520 - mean_absolute_error: 1.1415
# Epoch 80/100
# 13/13 - 0s - loss: 2.8194 - mean_absolute_error: 1.2198
# Epoch 81/100
# 13/13 - 0s - loss: 2.4374 - mean_absolute_error: 1.1332
# Epoch 82/100
# 13/13 - 0s - loss: 3.2039 - mean_absolute_error: 1.2700
# Epoch 83/100
# 13/13 - 0s - loss: 2.3734 - mean_absolute_error: 1.1304
# Epoch 84/100
# 13/13 - 0s - loss: 2.8871 - mean_absolute_error: 1.2268
# Epoch 85/100
# 13/13 - 0s - loss: 2.2278 - mean_absolute_error: 1.0728
# Epoch 86/100
# 13/13 - 0s - loss: 2.5999 - mean_absolute_error: 1.1839
# Epoch 87/100
# 13/13 - 0s - loss: 2.1980 - mean_absolute_error: 1.0603
# Epoch 88/100
# 13/13 - 0s - loss: 2.9525 - mean_absolute_error: 1.1844
# Epoch 89/100
# 13/13 - 0s - loss: 2.6094 - mean_absolute_error: 1.2198
# Epoch 90/100
# 13/13 - 0s - loss: 1.9438 - mean_absolute_error: 1.0334
# Epoch 91/100
# 13/13 - 0s - loss: 2.3908 - mean_absolute_error: 1.0965
# Epoch 92/100
# 13/13 - 0s - loss: 3.2380 - mean_absolute_error: 1.2248
# Epoch 93/100
# 13/13 - 0s - loss: 2.4331 - mean_absolute_error: 1.1558
# Epoch 94/100
# 13/13 - 0s - loss: 2.3649 - mean_absolute_error: 1.1134
# Epoch 95/100
# 13/13 - 0s - loss: 2.1190 - mean_absolute_error: 1.0818
# Epoch 96/100
# 13/13 - 0s - loss: 3.3164 - mean_absolute_error: 1.2600
# Epoch 97/100
# 13/13 - 0s - loss: 2.6350 - mean_absolute_error: 1.2027
# Epoch 98/100
# 13/13 - 0s - loss: 2.4361 - mean_absolute_error: 1.1153
# Epoch 99/100
# 13/13 - 0s - loss: 2.5553 - mean_absolute_error: 1.1768
# Epoch 100/100
# 13/13 - 0s - loss: 2.1650 - mean_absolute_error: 1.0788

# %%
loss, metrics= model.evaluate(x_test_scaled, y_test, batch_size=32, verbose=2)
# Out:
# 4/4 - 0s - loss: 27.4576 - mean_absolute_error: 4.1237

# %%
prediction= model.predict(x_test_scaled)

for i in range(10):
    print('Expected %.2f --> Predicted %.2f' % (prediction[i], y_test[i]))
# Out:
# Expected 5.20 --> Predicted 7.20
# Expected 16.30 --> Predicted 18.80
# Expected 17.53 --> Predicted 19.00
# Expected 29.50 --> Predicted 27.00
# Expected 20.27 --> Predicted 22.20
# Expected 22.21 --> Predicted 24.50
# Expected 24.72 --> Predicted 31.20
# Expected 17.79 --> Predicted 22.90
# Expected 16.59 --> Predicted 20.50
# Expected 18.58 --> Predicted 23.20

# %% [markdown]
# # Classification

# %%
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.utils import plot_model
from sklearn.model_selection import train_test_split

# %%
dataset= pd.read_csv('heart.csv')
dataset.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  heartdisease
# 0   0     1             1
# 1   0     2             1
# 2   0     2             1
# 3   0     2             1
# 4   0     2             1

# %%
x= dataset.iloc[:, 0:13]
y= dataset.iloc[:, 13:14]

# %%
x.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal
# 0   0     1
# 1   0     2
# 2   0     2
# 3   0     2
# 4   0     2

# %%
y.head()
# Out:
#    heartdisease
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1

# %%
print(x.shape, y.shape)
# Out:
# (303, 13) (303, 1)

# %%
x_train, x_test, y_train, y_test= train_test_split(x,y, test_size=0.3, random_state=10)
print(x_train.shape, x_test.shape, y_train.shape, y_test. shape)
# Out:
# (212, 13) (91, 13) (212, 1) (91, 1)

# %%
model= Sequential()
model.add(Dense(64, input_dim=15, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(16, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
plot_model(model, show_layer_names=True, show_shapes=True)

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(x_test, y_test, epochs=100, batch_size=100, verbose=1)
# Out:
# Epoch 1/100
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-7452595e7561> in <module>
# ----> 1 model.fit(x_test, y_test, epochs=100, batch_size=100, verbose=1)
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1182                 _r=1):
#    1183               callbacks.on_train_batch_begin(step)
# -> 1184               tmp_logs = self.train_function(iterator)
#    1185               if data_handler.should_sync:
#    1186                 context.async_wait()
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     883
#     884       with OptionalXlaContext(self._jit_compile):
# --> 885         result = self._call(*args, **kwds)
#     886
#     887       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     931       # This is the first call of __call__, so we have to initialize.
#     932       initializers = []
# --> 933       self._initialize(args, kwds, add_initializers_to=initializers)
#     934     finally:
#     935       # At this point we know that the initialization is complete (or less
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in _initialize(self, args, kwds, add_initializers_to)
#     758     self._concrete_stateful_fn = (
#     759         self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
# --> 760             *args, **kwds))
#     761
#     762     def invalid_creator_scope(*unused_args, **unused_kwds):
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    3064       args, kwargs = None, None
#    3065     with self._lock:
# -> 3066       graph_function, _ = self._maybe_define_function(args, kwargs)
#    3067     return graph_function
#    3068
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _maybe_define_function(self, args, kwargs)
#    3461
#    3462           self._function_cache.missed.add(call_context_key)
# -> 3463           graph_function = self._create_graph_function(args, kwargs)
#    3464           self._function_cache.primary[cache_key] = graph_function
#    3465
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3306             arg_names=arg_names,
#    3307             override_flat_arg_shapes=override_flat_arg_shapes,
# -> 3308             capture_by_value=self._capture_by_value),
#    3309         self._function_attributes,
#    3310         function_spec=self.function_spec,
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes, acd_record_initial_resource_uses)
#    1005         _, original_func = tf_decorator.unwrap(python_func)
#    1006
# -> 1007       func_outputs = python_func(*func_args, **func_kwargs)
#    1008
#    1009       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in wrapped_fn(*args, **kwds)
#     666         # the function a weak reference to itself to avoid a reference cycle.
#     667         with OptionalXlaContext(compile_with_xla):
# --> 668           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     669         return out
#     670
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py in wrapper(*args, **kwargs)
#     992           except Exception as e:  # pylint:disable=broad-except
#     993             if hasattr(e, "ag_error_metadata"):
# --> 994               raise e.ag_error_metadata.to_exception(e)
#     995             else:
#     996               raise
#
# ValueError: in user code:
#
#     C:\Users\Abdullah\Anaconda3\lib\site-packages\keras\engine\training.py:853 train_function  *
#         return step_function(self, iterator)
#     C:\Users\Abdullah\Anaconda3\lib\site-packages\keras\engine\training.py:842 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     C:\Users\Abdullah\Anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:1286 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     C:\Users\Abdullah\Anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2849 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     C:\Users\Abdullah\Anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3632 _call_for_each_replica
#         return fn(*args, **kwargs)
#     C:\Users\Abdullah\Anaconda3\lib\site-packages\keras\engine\training.py:835 run_step  **
#         outputs = model.train_step(data)
#     C:\Users\Abdullah\Anaconda3\lib\site-packages\keras\engine\training.py:787 train_step
#         y_pred = self(x, training=True)
#     C:\Users\Abdullah\Anaconda3\lib\site-packages\keras\engine\base_layer.py:1020 __call__
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     C:\Users\Abdullah\Anaconda3\lib\site-packages\keras\engine\input_spec.py:254 assert_input_compatibility
#         ' but received input with shape ' + display_shape(x.shape))
#
#     ValueError: Input 0 of layer sequential is incompatible with the layer: expected axis -1 of input shape to have value 15 but received input with shape (None, 13)

# %%
loss, accuracy= model.evaluate(x_test, y_test, verbose=2)

# %% [markdown]
# # Multiclass Classification

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.utils import plot_model, to_categorical
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt
import numpy as np

# %%
(x_train, y_train),(x_test, y_test)= mnist.load_data()

# %%
print(x_train.shape, y_train.shape,  y_test.shape)
# Out:
# (60000, 28, 28) (60000,) (10000,)

# %%
# display training data
plt.imshow(x_train[298], cmap='Greys')
print(y_train[298])
# Out:
# 3

# %%
# reshape input fromn (28,28) to 784
x_train= x_train.reshape(60000, 784)
x_test= x_test.reshape(10000, 784)

# %%
# converting values to float
x_train= x_train.astype('float32')
x_test= x_test.astype('float32')

# %%
# normalizing RGB code 
x_train /= 255
x_test /= 255

# %%
# to_categorical is used to convert vector to binary matrix
y_train= to_categorical(y_train, 10)
y_test= to_categorical(y_test, 10)

print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
# Out:
# (60000, 784) (10000, 784) (60000, 10) (10000, 10)

# %%
model= Sequential()
model.add(Dense(512, input_dim=784, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))

# %%
plot_model(model, show_layer_names=True, show_shapes=True)

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['categorical_accuracy'])

# %%
model.fit(x_train, y_train, batch_size=128, epochs=10, verbose=1)
# Out:
# Epoch 1/10
# 469/469 [==============================] - 9s 14ms/step - loss: 0.2473 - categorical_accuracy: 0.9261
# Epoch 2/10
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0921 - categorical_accuracy: 0.9720
# Epoch 3/10
# 469/469 [==============================] - 6s 14ms/step - loss: 0.0622 - categorical_accuracy: 0.9810
# Epoch 4/10
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0470 - categorical_accuracy: 0.9848
# Epoch 5/10
# 469/469 [==============================] - 7s 14ms/step - loss: 0.0356 - categorical_accuracy: 0.9887
# Epoch 6/10
# 469/469 [==============================] - 7s 14ms/step - loss: 0.0278 - categorical_accuracy: 0.9913 0s - loss: 0.0280 - categorical_accuracy:
# Epoch 7/10
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0247 - categorical_accuracy: 0.9918 0s - loss: 0.0246 -
# Epoch 8/10
# 469/469 [==============================] - 7s 14ms/step - loss: 0.0206 - categorical_accuracy: 0.9934
# Epoch 9/10
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0205 - categorical_accuracy: 0.9935
# Epoch 10/10
# 469/469 [==============================] - 7s 14ms/step - loss: 0.0165 - categorical_accuracy: 0.9946

# %%
loss, accuracy= model.evaluate(x_test, y_test, verbose=1)
# Out:
# 313/313 [==============================] - 2s 4ms/step - loss: 0.0898 - categorical_accuracy: 0.9777

# %%
print(loss)
print(accuracy)
# Out:
# 0.08979368954896927
# 0.9776999950408936

# %%
pred= model.predict(x_test)
pred= np.argmax(pred, axis=1)[:]
label= np.argmax(y_test, axis=1)

print(pred)
print(label)
# Out:
# [7 2 1 ... 4 5 6]
# [7 2 1 ... 4 5 6]

# %%
for i in range(20):
    print('Expected %d ---> Predicted %d' % (label[i], pred[i]))
# Out:
# Expected 7 ---> Predicted 7
# Expected 2 ---> Predicted 2
# Expected 1 ---> Predicted 1
# Expected 0 ---> Predicted 0
# Expected 4 ---> Predicted 4
# Expected 1 ---> Predicted 1
# Expected 4 ---> Predicted 4
# Expected 9 ---> Predicted 9
# Expected 5 ---> Predicted 6
# Expected 9 ---> Predicted 9
# Expected 0 ---> Predicted 0
# Expected 6 ---> Predicted 6
# Expected 9 ---> Predicted 9
# Expected 0 ---> Predicted 0
# Expected 1 ---> Predicted 1
# Expected 5 ---> Predicted 5
# Expected 9 ---> Predicted 9
# Expected 7 ---> Predicted 7
# Expected 3 ---> Predicted 3
# Expected 4 ---> Predicted 4
